# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":['rohan','harris','abcd','megha'],
    "marks":[45,42,30,50],
    "city":['Patna','Delhi','Chandigarh','Kolkata']
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks        city
# 0   rohan     45       Patna
# 1  harris     42       Delhi
# 2    abcd     30  Chandigarh
# 3   megha     50     Kolkata

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('indexFalse_friends.csv',index=False)

# %%
df.head(2)
# Out:
#      name  marks   city
# 0   rohan     45  Patna
# 1  harris     42  Delhi

# %%
df.tail(2)
# Out:
#     name  marks        city
# 2   abcd     30  Chandigarh
# 3  megha     50     Kolkata

# %%
df.describe()
# Out:
#        marks
# count   4.00
# mean   41.75
# std     8.50
# min    30.00
# 25%    39.00
# 50%    43.50
# 75%    46.25
# max    50.00

# %%
my_file=pd.read_csv('Class.csv')

# %%
my_file
# Out:
#      name stream     ph. no.
# 0   rohan    CSE  1212121212
# 1  harris     IT  2323232323
# 2    abcd     CE  3434343434
# 3   megha    ECE  4545454545

# %%
my_file['stream']
# Out:
# 0    CSE
# 1     IT
# 2     CE
# 3    ECE
# Name: stream, dtype: object

# %%
my_file['stream'][0]
# Out:
# 'CSE'

# %%
my_file['stream'][0]='ME'
# Out:
# C:\Users\Upaneeta\AppData\Local\Temp/ipykernel_1400/120452562.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_file['stream'][0]='ME'

# %%
my_file
# Out:
#      name stream     ph. no.
# 0   rohan     ME  1212121212
# 1  harris     IT  2323232323
# 2    abcd     CE  3434343434
# 3   megha    ECE  4545454545

# %%
my_file.to_csv('NewClass.csv')

# %%
my_file.index=['first','second','third','fourth']

# %%
my_file
# Out:
#           name stream     ph. no.
# first    rohan     ME  1212121212
# second  harris     IT  2323232323
# third     abcd     CE  3434343434
# fourth   megha    ECE  4545454545

# %%
ser= pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.457269
# 1     0.928141
# 2     0.755947
# 3     0.394167
# 4     0.618117
# 5     0.871837
# 6     0.970149
# 7     0.160133
# 8     0.604110
# 9     0.769809
# 10    0.001410
# 11    0.157477
# 12    0.675020
# 13    0.604074
# 14    0.672960
# 15    0.536223
# 16    0.434619
# 17    0.486917
# 18    0.563219
# 19    0.531858
# 20    0.488805
# 21    0.434159
# 22    0.571971
# 23    0.770151
# 24    0.416305
# 25    0.953668
# 26    0.053829
# 27    0.489611
# 28    0.539994
# 29    0.461129
# 30    0.862519
# 31    0.651640
# 32    0.715154
# 33    0.156778
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf= pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.754376  0.595025  0.846291  0.303203  0.264520
# 1    0.596777  0.623876  0.269151  0.921824  0.119067
# 2    0.322069  0.037494  0.345636  0.292825  0.734223
# 3    0.422643  0.494234  0.493719  0.006279  0.816325
# 4    0.361289  0.499726  0.756223  0.094873  0.580164
# ..        ...       ...       ...       ...       ...
# 329  0.227145  0.927769  0.981765  0.718669  0.103477
# 330  0.172166  0.830578  0.183650  0.102850  0.853148
# 331  0.683084  0.189385  0.794411  0.475515  0.479066
# 332  0.147072  0.078493  0.245172  0.703416  0.975669
# 333  0.694319  0.615759  0.812919  0.988624  0.352858
#
# [334 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
# 332  0.147072  0.078493  0.245172  0.703416  0.975669  NaN
# 333  0.694319  0.615759  0.812919  0.988624  0.352858  NaN
#
# [334 rows x 6 columns]

# %%
newdf.drop(0,axis=1)
# Out:
#             A         B         C         D         E
# 0           3  0.595025  0.846291  0.303203  0.264520
# 1    0.596777  0.623876  0.269151  0.921824  0.119067
# 2    0.322069  0.037494  0.345636  0.292825  0.734223
# 3    0.422643  0.494234  0.493719  0.006279  0.816325
# 4    0.361289  0.499726  0.756223  0.094873  0.580164
# ..        ...       ...       ...       ...       ...
# 329  0.227145  0.927769  0.981765  0.718669  0.103477
# 330  0.172166  0.830578  0.183650  0.102850  0.853148
# 331  0.683084  0.189385  0.794411  0.475515  0.479066
# 332  0.147072  0.078493  0.245172  0.703416  0.975669
# 333  0.694319  0.615759  0.812919  0.988624  0.352858
#
# [334 rows x 5 columns]

# %%
newdf
# Out:
#             A         B         C         D         E    0
# 0           3  0.595025  0.846291  0.303203  0.264520  5.0
# 1    0.596777  0.623876  0.269151  0.921824  0.119067  NaN
# 2    0.322069  0.037494  0.345636  0.292825  0.734223  NaN
# 3    0.422643  0.494234  0.493719  0.006279  0.816325  NaN
# 4    0.361289  0.499726  0.756223  0.094873  0.580164  NaN
# ..        ...       ...       ...       ...       ...  ...
# 329  0.227145  0.927769  0.981765  0.718669  0.103477  NaN
# 330  0.172166  0.830578  0.183650  0.102850  0.853148  NaN
# 331  0.683084  0.189385  0.794411  0.475515  0.479066  NaN
# 332  0.147072  0.078493  0.245172  0.703416  0.975669  NaN
# 333  0.694319  0.615759  0.812919  0.988624  0.352858  NaN
#
# [334 rows x 6 columns]

# %%
newdf=newdf.drop(0,axis=1)

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0         3  0.595025  0.846291  0.303203  0.264520
# 1  0.596777  0.623876  0.269151  0.921824  0.119067
# 2  0.322069  0.037494  0.345636  0.292825  0.734223
# 3  0.422643  0.494234  0.493719  0.006279  0.816325
# 4  0.361289  0.499726  0.756223  0.094873  0.580164

# %%
newdf.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.269151  0.921824
# 2  0.345636  0.292825

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0         3  0.595025  0.846291  0.303203  0.264520
# 1  0.596777  0.623876  0.269151  0.921824  0.119067
# 2  0.322069  0.037494  0.345636  0.292825  0.734223
# 3  0.422643  0.494234  0.493719  0.006279  0.816325
# 4  0.361289  0.499726  0.756223  0.094873  0.580164

# %%
newdf.loc[:,['A']]
# Out:
#             A
# 0           3
# 1    0.596777
# 2    0.322069
# 3    0.422643
# 4    0.361289
# ..        ...
# 329  0.227145
# 330  0.172166
# 331  0.683084
# 332  0.147072
# 333  0.694319
#
# [334 rows x 1 columns]

# %%
newdf.loc[[1,2],:]
# Out:
#           A         B         C         D         E
# 1  0.596777  0.623876  0.269151  0.921824  0.119067
# 2  0.322069  0.037494  0.345636  0.292825  0.734223

# %%
newdf.loc[newdf['A']<0.3]
# Out:
#             A         B         C         D         E
# 6     0.22955  0.396038  0.488244  0.651992  0.112815
# 7     0.24287  0.468174  0.209396  0.497413  0.417760
# 8    0.248667  0.385238  0.482577  0.170768  0.807894
# 19   0.191382  0.420765  0.201008  0.860826  0.292065
# 20   0.249435  0.792932  0.078541  0.500032  0.492628
# ..        ...       ...       ...       ...       ...
# 326  0.052373  0.652679  0.928228  0.124936  0.594948
# 327  0.035344  0.832866  0.294925  0.557953  0.038197
# 329  0.227145  0.927769  0.981765  0.718669  0.103477
# 330  0.172166  0.830578  0.183650  0.102850  0.853148
# 332  0.147072  0.078493  0.245172  0.703416  0.975669
#
# [81 rows x 5 columns]

# %%
newdf.loc[(newdf['A']<0.1) & (newdf['C']>0.5)]
# Out:
#             A         B         C         D         E
# 23   0.016366  0.591137  0.840280  0.582052  0.391704
# 27   0.090211  0.189071  0.943721  0.679690  0.890045
# 68    0.02032  0.133637  0.541738  0.681930  0.299024
# 72   0.008753  0.372272  0.901035  0.307050  0.402450
# 86   0.063469  0.356128  0.577574  0.201194  0.400238
# 136  0.093303  0.905128  0.657428  0.028660  0.981843
# 162   0.07748  0.095324  0.850317  0.273633  0.522935
# 164  0.087218  0.777052  0.724351  0.570735  0.629654
# 222  0.037682  0.471932  0.529385  0.748596  0.321441
# 263   0.03408  0.875360  0.782148  0.905360  0.059036
# 300  0.098346  0.835655  0.512918  0.146687  0.475414
# 305  0.013834  0.144653  0.715401  0.673890  0.360086
# 323  0.072785  0.715775  0.720901  0.996600  0.885725
# 326  0.052373  0.652679  0.928228  0.124936  0.594948

# %%
newdf.iloc[(85,4)]
# Out:
# 0.7565753614556089

# %%
newdf.iloc[[89,309], [2,4]]
# Out:
#             C         E
# 89   0.174714  0.574062
# 309  0.014690  0.259085

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0         3  0.595025  0.846291  0.303203  0.264520
# 1  0.596777  0.623876  0.269151  0.921824  0.119067
# 2  0.322069  0.037494  0.345636  0.292825  0.734223
# 3  0.422643  0.494234  0.493719  0.006279  0.816325
# 4  0.361289  0.499726  0.756223  0.094873  0.580164

# %%
newdf.drop(3)
# Out:
#             A         B         C         D         E
# 0           3  0.595025  0.846291  0.303203  0.264520
# 1    0.596777  0.623876  0.269151  0.921824  0.119067
# 2    0.322069  0.037494  0.345636  0.292825  0.734223
# 4    0.361289  0.499726  0.756223  0.094873  0.580164
# 5    0.871915  0.398475  0.821828  0.339894  0.380605
# ..        ...       ...       ...       ...       ...
# 329  0.227145  0.927769  0.981765  0.718669  0.103477
# 330  0.172166  0.830578  0.183650  0.102850  0.853148
# 331  0.683084  0.189385  0.794411  0.475515  0.479066
# 332  0.147072  0.078493  0.245172  0.703416  0.975669
# 333  0.694319  0.615759  0.812919  0.988624  0.352858
#
# [333 rows x 5 columns]

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0         3  0.595025  0.846291  0.303203  0.264520
# 1  0.596777  0.623876  0.269151  0.921824  0.119067
# 2  0.322069  0.037494  0.345636  0.292825  0.734223
# 3  0.422643  0.494234  0.493719  0.006279  0.816325
# 4  0.361289  0.499726  0.756223  0.094873  0.580164

# %%
newdf.drop(['A','D'],axis=1)
# Out:
#             B         C         E
# 0    0.595025  0.846291  0.264520
# 1    0.623876  0.269151  0.119067
# 2    0.037494  0.345636  0.734223
# 3    0.494234  0.493719  0.816325
# 4    0.499726  0.756223  0.580164
# ..        ...       ...       ...
# 329  0.927769  0.981765  0.103477
# 330  0.830578  0.183650  0.853148
# 331  0.189385  0.794411  0.479066
# 332  0.078493  0.245172  0.975669
# 333  0.615759  0.812919  0.352858
#
# [334 rows x 3 columns]

# %% [markdown]
# **'inplace' modifies the original content**

# %%
newdf.drop(['A','D'],axis=1,inplace=True)

# %%
newdf
# Out:
#             B         C         E
# 0    0.595025  0.846291  0.264520
# 1    0.623876  0.269151  0.119067
# 2    0.037494  0.345636  0.734223
# 3    0.494234  0.493719  0.816325
# 4    0.499726  0.756223  0.580164
# ..        ...       ...       ...
# 329  0.927769  0.981765  0.103477
# 330  0.830578  0.183650  0.853148
# 331  0.189385  0.794411  0.479066
# 332  0.078493  0.245172  0.975669
# 333  0.615759  0.812919  0.352858
#
# [334 rows x 3 columns]

# %%
newdf.drop([1,3],axis=0,inplace=True)

# %%
newdf.head()
# Out:
#           B         C         E
# 0  0.595025  0.846291  0.264520
# 2  0.037494  0.345636  0.734223
# 4  0.499726  0.756223  0.580164
# 5  0.398475  0.821828  0.380605
# 6  0.396038  0.488244  0.112815

# %%
newdf.reset_index()
# Out:
#      index         B         C         E
# 0        0  0.595025  0.846291  0.264520
# 1        2  0.037494  0.345636  0.734223
# 2        4  0.499726  0.756223  0.580164
# 3        5  0.398475  0.821828  0.380605
# 4        6  0.396038  0.488244  0.112815
# ..     ...       ...       ...       ...
# 327    329  0.927769  0.981765  0.103477
# 328    330  0.830578  0.183650  0.853148
# 329    331  0.189385  0.794411  0.479066
# 330    332  0.078493  0.245172  0.975669
# 331    333  0.615759  0.812919  0.352858
#
# [332 rows x 4 columns]

# %% [markdown]
# **To remove the index column**

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf.head()
# Out:
#           B         C         E
# 0  0.595025  0.846291  0.264520
# 1  0.037494  0.345636  0.734223
# 2  0.499726  0.756223  0.580164
# 3  0.398475  0.821828  0.380605
# 4  0.396038  0.488244  0.112815

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: B, Length: 332, dtype: bool

# %%
newdf['A']='None'

# %% [markdown]
# **For setting a value to a particular cell or column or row, always use loc or iloc. Never change it directly.**

# %%
newdf.loc[:,['B']]=56

# %%
newdf
# Out:
#       B         C         E     A
# 0    56  0.846291  0.264520  None
# 1    56  0.345636  0.734223  None
# 2    56  0.756223  0.580164  None
# 3    56  0.821828  0.380605  None
# 4    56  0.488244  0.112815  None
# ..   ..       ...       ...   ...
# 327  56  0.981765  0.103477  None
# 328  56  0.183650  0.853148  None
# 329  56  0.794411  0.479066  None
# 330  56  0.245172  0.975669  None
# 331  56  0.812919  0.352858  None
#
# [332 rows x 4 columns]

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(how='any',axis=1)
# Out:
#        name
# 0    Alfred
# 1    Batman
# 2  Catwoman

# %%
df.dropna(how='all',axis=1)
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df = pd.DataFrame({"name": ['Alfred','Alfred', 'Alfred'],
                   "toy": ['Batmobile', 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, 'Batmobile',
                            pd.NaT]})

# %%
df.drop_duplicates(subset=['name'])
# Out:
#      name        toy born
# 0  Alfred  Batmobile  NaT

# %%
df.drop_duplicates(subset=['name'],keep='last')
# Out:
#      name       toy born
# 2  Alfred  Bullwhip  NaT

# %%
df.drop_duplicates(subset=['name'],keep='first')
# Out:
#      name        toy born
# 0  Alfred  Batmobile  NaT

# %%
df.drop_duplicates(subset=['name'],keep=False)
# Out:
# Empty DataFrame
# Columns: [name, toy, born]
# Index: []

# %%
df.info
# Out:
# <bound method DataFrame.info of      name        toy       born
# 0  Alfred  Batmobile        NaT
# 1  Alfred  Batmobile  Batmobile
# 2  Alfred   Bullwhip        NaT>

# %%
df.shape
# Out:
# (3, 3)

# %%
df['name'].value_counts(dropna=False)
# Out:
# Alfred    3
# Name: name, dtype: int64

# %%
df['born'].value_counts(dropna=True)
# Out:
# Batmobile    1
# Name: born, dtype: int64

# %%
df.isnull()
# Out:
#     name    toy   born
# 0  False  False   True
# 1  False  False  False
# 2  False  False   True

# %%
df.notnull()
# Out:
#    name   toy   born
# 0  True  True  False
# 1  True  True   True
# 2  True  True  False

# %%
data=pd.read_excel('My_data.xlsx')

# %%
data1=pd.read_excel('My_data.xlsx',sheet_name='Sheet_1')

# %%
data2=pd.read_excel('My_data.xlsx',sheet_name='Sheet_2')

# %%
data
# Out:
#    Sl No.  Stream  No. of Students  Defaulters
# 0       1     CSE               50           5
# 1       2      IT               30           3
# 2       3     ECE               40           0
# 3       4    AEIE               35           3
# 4       5     BME               20           1

# %%
data1
# Out:
#    Sl No.  Stream  No. of Students  Defaulters
# 0       1     CSE               50           5
# 1       2      IT               30           3
# 2       3     ECE               40           0
# 3       4    AEIE               35           3
# 4       5     BME               20           1

# %%
data2
# Out:
#    Sl No.  Stream  No. of Students  Defaulters
# 0      11     CSE               50           5
# 1      12      IT               30           3
# 2      13     ECE               40           0
# 3      14    AEIE               35           3
# 4      15     BME               20           1

# %%
data2.iloc[3,3]=6

# %%
data2
# Out:
#    Sl No.  Stream  No. of Students  Defaulters
# 0      11     CSE               50           5
# 1      12      IT               30           3
# 2      13     ECE               40           0
# 3      14    AEIE               35           6
# 4      15     BME               20           1

# %%
data2.to_excel('My_data.xlsx',sheet_name='Sheet_2')

# %%
with pd.ExcelWriter('My_data.xlsx') as writer:  
    data1.to_excel(writer, sheet_name='Sheet_1')
    data2.to_excel(writer, sheet_name='Sheet_2')
